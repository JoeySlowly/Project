# %%
import plotly.io as pio

pio.renderers.default = "vscode+jupyterlab+notebook_connected"

# %% [markdown]
# Which sectors of the U.S. stock market performed the best and worst during the 2022 rate hike cycle, and why?

# %% [markdown]
# Assumption:
# Best performer:
# Defensive sectors (consumer staples and utilitie)
#     - stable, relatively not sensitive to interest rate fluctuation
#
# Worst performer:
# Real Estate （XLRE）
#     - not performing well before rate hike (decreasing demand, structural challenge)
#     - sensitive to high borrowing cost during rate hike

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
etfs = ['XLK', 'XLY', 'XLP', 'XLE', 'XLF', 'XLV', 'XLI', 'XLB', 'XLRE', 'XLU', 'XLC']
data = yf.download(etfs, start='2020-01-01', end='2023-12-31')['Adj Close']
data
# Out:
# [*********************100%***********************]  11 of 11 completed
# Ticker            XLB        XLC        XLE        XLF         XLI  \
# Date
# 2020-01-02  55.125385  51.972885  48.995480  28.291931   76.781731
# 2020-01-03  54.235386  51.637653  48.849903  27.991535   76.633736
# 2020-01-06  53.999264  52.327290  49.230019  27.973326   76.661484
# 2020-01-07  53.935692  52.394356  49.100620  27.791269   76.504234
# 2020-01-08  54.126404  52.767902  48.291851  27.973326   76.763252
# ...               ...        ...        ...        ...         ...
# 2023-12-22  84.512009  72.004524  82.942223  36.919331  112.031601
# 2023-12-26  84.906929  72.282181  83.654716  37.067646  112.823830
# 2023-12-27  85.114250  72.292107  83.283829  37.186291  112.992180
# 2023-12-28  84.788452  72.490440  82.014999  37.295052  113.021889
# 2023-12-29  84.452774  72.054108  81.829552  37.176403  112.883247
#
# Ticker             XLK        XLP       XLRE        XLU         XLV  \
# Date
# 2020-01-02   89.397301  55.159161  32.645725  54.858837   94.742851
# 2020-01-03   88.392189  55.070885  32.884884  54.970600   93.917213
# 2020-01-06   88.602776  55.185650  32.893417  55.022194   94.501656
# 2020-01-07   88.564484  54.761894  32.534691  54.944813   94.316109
# 2020-01-08   89.512169  54.964943  32.696964  54.919022   94.928368
# ...                ...        ...        ...        ...         ...
# 2023-12-22  191.054443  69.798813  38.792553  61.195446  133.511154
# 2023-12-26  191.850296  70.092827  39.075710  61.566803  133.807800
# 2023-12-27  191.840347  70.416237  39.300285  61.527714  134.371429
# 2023-12-28  192.069153  70.445641  39.544384  61.967476  134.717514
# 2023-12-29  191.482208  70.592651  39.114765  61.889297  134.855957
#
# Ticker             XLY
# Date
# 2020-01-02  121.825500
# 2020-01-03  120.788757
# 2020-01-06  121.124763
# 2020-01-07  120.932770
# 2020-01-08  121.297531
# ...                ...
# 2023-12-22  178.337463
# 2023-12-26  179.092636
# 2023-12-27  179.708694
# 2023-12-28  178.774673
# 2023-12-29  177.671722
#
# [1006 rows x 11 columns]

# %%
returns = data.pct_change()
returns
# Out:
# Ticker           XLB       XLC       XLE       XLF       XLI       XLK  \
# Date
# 2020-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-01-03 -0.016145 -0.006450 -0.002971 -0.010618 -0.001927 -0.011243
# 2020-01-06 -0.004354  0.013355  0.007781 -0.000651  0.000362  0.002382
# 2020-01-07 -0.001177  0.001282 -0.002628 -0.006508 -0.002051 -0.000432
# 2020-01-08  0.003536  0.007130 -0.016472  0.006551  0.003386  0.010701
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-22  0.006230  0.000138  0.002951  0.002147  0.004796  0.001303
# 2023-12-26  0.004673  0.003856  0.008590  0.004017  0.007071  0.004166
# 2023-12-27  0.002442  0.000137 -0.004434  0.003201  0.001492 -0.000052
# 2023-12-28 -0.003828  0.002744 -0.015235  0.002925  0.000263  0.001193
# 2023-12-29 -0.003959 -0.006019 -0.002261 -0.003181 -0.001227 -0.003056
#
# Ticker           XLP      XLRE       XLU       XLV       XLY
# Date
# 2020-01-02       NaN       NaN       NaN       NaN       NaN
# 2020-01-03 -0.001600  0.007326  0.002037 -0.008715 -0.008510
# 2020-01-06  0.002084  0.000259  0.000939  0.006223  0.002782
# 2020-01-07 -0.007679 -0.010906 -0.001406 -0.001963 -0.001585
# 2020-01-08  0.003708  0.004988 -0.000469  0.006492  0.003016
# ...              ...       ...       ...       ...       ...
# 2023-12-22  0.007640  0.004043  0.003365  0.004987 -0.007356
# 2023-12-26  0.004212  0.007299  0.006068  0.002222  0.004235
# 2023-12-27  0.004614  0.005747 -0.000635  0.004212  0.003440
# 2023-12-28  0.000418  0.006211  0.007147  0.002576 -0.005197
# 2023-12-29  0.002087 -0.010864 -0.001262  0.001028 -0.006170
#
# [1006 rows x 11 columns]

# %%
covid_period = data.loc['2020-01-01':'2020-12-31']
hike_period = data.loc['2022-01-01':'2022-12-31']

# %% [markdown]
# returns during the covid and the rate hike

# %%
cumulative_returns_covid = (1 + returns.loc['2020-01-01':'2020-12-31']).cumprod()
cumulative_returns_hike = (1 + returns.loc['2022-01-01':'2022-12-31']).cumprod()

# %%
volatility_covid = returns.loc['2020-01-01':'2020-12-31'].std()
volatility_hike = returns.loc['2022-01-01':'2022-12-31'].std()

# %%
volatility_covid
# Out:
# Ticker
# XLB     0.024178
# XLC     0.020928
# XLE     0.038115
# XLF     0.028580
# XLI     0.024945
# XLK     0.025329
# XLP     0.017561
# XLRE    0.025201
# XLU     0.024300
# XLV     0.019225
# XLY     0.021271
# dtype: float64

# %%
volatility_hike
# Out:
# Ticker
# XLB     0.015924
# XLC     0.019431
# XLE     0.022223
# XLF     0.015428
# XLI     0.013795
# XLK     0.020680
# XLP     0.011067
# XLRE    0.016081
# XLU     0.013454
# XLV     0.011972
# XLY     0.021595
# dtype: float64

# %%
plt.figure(figsize=(10, 6))
cumulative_returns_covid.plot(title='Cumulative Returns During the 2020 Pandemic')
plt.ylabel('Cumulative Returns')
plt.show()

# %% [markdown]
# Tech outperformed.
# Energy struggled.

# %%
plt.figure(figsize=(10, 6))
cumulative_returns_hike.plot(title='Cumulative Returns During the 2022 Interest Rate Hike')
plt.ylabel('Cumulative Returns')
plt.show()

# %% [markdown]
# Winner: Energy Sector
#
# Energy Sector (XLE) Outperformed Significantly
#     This is likely due to the surge in energy prices (especially oil and gas) in 2022, which boosted the profitability of energy companies.
#     This aligns with the global energy crisis and soaring oil prices during that period.
#
# Consumer Discretionary (XLY) and Technology (XLK) Struggled
#
# Defensive Sectors Were More Stable:
#     Utilities (XLU) and Consumer Staples (XLP) showed relatively stable trends. While they did not experience significant growth, they avoided steep declines.
#     These sectors tend to perform better during uncertain economic conditions due to their stable cash flows and inelastic demand.

# %% [markdown]
# ## Look into Engergy Sector a bit

# %% [markdown]
# What affected Energy Sector during the rate hike?
# - interest rate
#     - capital intensive industry
#     - higher borrowing cost
# - geopolitical event
#     - higher fuel price (2022 Russian-Ukrainian war)

# %% [markdown]
# Let's try to break it down and run a regression.

# %% [markdown]
# interest rate - 10-Year Treasury Yield

# %%
tnx = yf.download('^TNX', start='2020-01-01', end='2023-12-31')
tnx
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price      Adj Close  Close   High    Low   Open Volume
# Ticker          ^TNX   ^TNX   ^TNX   ^TNX   ^TNX   ^TNX
# Date
# 2020-01-02     1.882  1.882  1.903  1.851  1.903      0
# 2020-01-03     1.788  1.788  1.840  1.786  1.828      0
# 2020-01-06     1.811  1.811  1.816  1.766  1.785      0
# 2020-01-07     1.827  1.827  1.828  1.797  1.797      0
# 2020-01-08     1.874  1.874  1.876  1.802  1.823      0
# ...              ...    ...    ...    ...    ...    ...
# 2023-12-22     3.901  3.901  3.919  3.849  3.852      0
# 2023-12-26     3.886  3.886  3.908  3.882  3.908      0
# 2023-12-27     3.789  3.789  3.852  3.785  3.852      0
# 2023-12-28     3.850  3.850  3.861  3.800  3.818      0
# 2023-12-29     3.866  3.866  3.898  3.847  3.879      0
#
# [1006 rows x 6 columns]

# %%
crude_oil = yf.download('CL=F', start='2020-01-01', end='2023-12-31')
crude_oil
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price       Adj Close      Close       High        Low       Open   Volume
# Ticker           CL=F       CL=F       CL=F       CL=F       CL=F     CL=F
# Date
# 2020-01-02  61.180000  61.180000  61.599998  60.639999  61.599998   486873
# 2020-01-03  63.049999  63.049999  64.089996  61.130001  61.180000   885861
# 2020-01-06  63.270000  63.270000  64.720001  62.639999  63.709999   724236
# 2020-01-07  62.700001  62.700001  63.150002  62.110001  62.910000   582649
# 2020-01-08  59.610001  59.610001  65.650002  59.150002  62.840000  1205710
# ...               ...        ...        ...        ...        ...      ...
# 2023-12-22  73.559998  73.559998  74.980003  73.389999  73.910004   222600
# 2023-12-26  75.570000  75.570000  76.180000  73.129997  73.559998   208715
# 2023-12-27  74.110001  74.110001  75.660004  73.769997  75.320000   253323
# 2023-12-28  71.769997  71.769997  74.400002  71.720001  73.800003   262748
# 2023-12-29  71.650002  71.650002  72.620003  71.250000  71.989998   214486
#
# [1006 rows x 6 columns]

# %%
xle_returns = returns[['XLE']].copy()
xle_returns.rename(columns={'XLE': 'XLE_Returns'}, inplace=True)
xle_returns
# Out:
# Ticker      XLE_Returns
# Date
# 2020-01-02          NaN
# 2020-01-03    -0.002971
# 2020-01-06     0.007781
# 2020-01-07    -0.002628
# 2020-01-08    -0.016472
# ...                 ...
# 2023-12-22     0.002951
# 2023-12-26     0.008590
# 2023-12-27    -0.004434
# 2023-12-28    -0.015235
# 2023-12-29    -0.002261
#
# [1006 rows x 1 columns]

# %%
tnx_cleaned = tnx[['Adj Close']].copy()
tnx_cleaned.rename(columns={'Adj Close': 'Interest_Rate'}, inplace=True)
crude_cleaned = crude_oil[['Adj Close']].copy()
crude_cleaned.rename(columns={'Adj Close': 'Crude_Oil_Price'}, inplace=True)

# %%
merged_data = pd.concat([xle_returns, tnx_cleaned, crude_cleaned], axis=1)
merged_data
# Out:
#             XLE_Returns  (Interest_Rate, ^TNX)  (Crude_Oil_Price, CL=F)
# Date
# 2020-01-02          NaN                  1.882                61.180000
# 2020-01-03    -0.002971                  1.788                63.049999
# 2020-01-06     0.007781                  1.811                63.270000
# 2020-01-07    -0.002628                  1.827                62.700001
# 2020-01-08    -0.016472                  1.874                59.610001
# ...                 ...                    ...                      ...
# 2023-12-22     0.002951                  3.901                73.559998
# 2023-12-26     0.008590                  3.886                75.570000
# 2023-12-27    -0.004434                  3.789                74.110001
# 2023-12-28    -0.015235                  3.850                71.769997
# 2023-12-29    -0.002261                  3.866                71.650002
#
# [1006 rows x 3 columns]

# %%
merged_data.dropna(inplace=True)
merged_data.rename(columns={
    'XLE_Returns': 'XLE_Returns',
    '(Interest_Rate, ^TNX)': 'Interest_Rate',
    '(Crude_Oil_Price, CL=F)': 'Crude_Oil_Price'
}, inplace=True)
merged_data
# Out:
#             XLE_Returns  (Interest_Rate, ^TNX)  (Crude_Oil_Price, CL=F)
# Date
# 2020-01-03    -0.002971                  1.788                63.049999
# 2020-01-06     0.007781                  1.811                63.270000
# 2020-01-07    -0.002628                  1.827                62.700001
# 2020-01-08    -0.016472                  1.874                59.610001
# 2020-01-09     0.007369                  1.858                59.560001
# ...                 ...                    ...                      ...
# 2023-12-22     0.002951                  3.901                73.559998
# 2023-12-26     0.008590                  3.886                75.570000
# 2023-12-27    -0.004434                  3.789                74.110001
# 2023-12-28    -0.015235                  3.850                71.769997
# 2023-12-29    -0.002261                  3.866                71.650002
#
# [1005 rows x 3 columns]

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /Users/joey/opt/anaconda3/envs/study/lib/python3.10/site-packages (0.14.4)
# Requirement already satisfied: packaging>=21.3 in /Users/joey/opt/anaconda3/envs/study/lib/python3.10/site-packages (from statsmodels) (24.1)
# Requirement already satisfied: patsy>=0.5.6 in /Users/joey/opt/anaconda3/envs/study/lib/python3.10/site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /Users/joey/opt/anaconda3/envs/study/lib/python3.10/site-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: numpy<3,>=1.22.3 in /Users/joey/opt/anaconda3/envs/study/lib/python3.10/site-packages (from statsmodels) (2.1.2)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /Users/joey/opt/anaconda3/envs/study/lib/python3.10/site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/joey/opt/anaconda3/envs/study/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/joey/opt/anaconda3/envs/study/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/joey/opt/anaconda3/envs/study/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0)
# Requirement already satisfied: six>=1.5 in /Users/joey/opt/anaconda3/envs/study/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm

# %%
merged_data.rename(columns={
    '(Interest_Rate, ^TNX)': 'Interest_Rate',
    '(Crude_Oil_Price, CL=F)': 'Crude_Oil_Price'
}, inplace=True)

# %%
merged_data.columns = ['XLE_Returns', 'Interest_Rate', 'Crude_Oil_Price']

# %%
print(merged_data.columns)
# Out:
# Index(['XLE_Returns', 'Interest_Rate', 'Crude_Oil_Price'], dtype='object')

# %%
Y = merged_data['XLE_Returns']
X = merged_data[['Interest_Rate', 'Crude_Oil_Price']]
X = sm.add_constant(X) 
model = sm.OLS(Y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            XLE_Returns   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.081
# Date:                Fri, 06 Dec 2024   Prob (F-statistic):              0.340
# Time:                        16:21:10   Log-Likelihood:                 2281.8
# No. Observations:                1005   AIC:                            -4558.
# Df Residuals:                    1002   BIC:                            -4543.
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              -0.0020      0.003     -0.772      0.440      -0.007       0.003
# Interest_Rate      -0.0008      0.001     -1.054      0.292      -0.002       0.001
# Crude_Oil_Price  6.866e-05   4.69e-05      1.465      0.143   -2.33e-05       0.000
# ==============================================================================
# Omnibus:                      202.390   Durbin-Watson:                   2.111
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3767.232
# Skew:                          -0.364   Prob(JB):                         0.00
# Kurtosis:                      12.457   Cond. No.                         243.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# P > 0.05

# %%
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt

# %%
def check_stationarity(series, name):
    result = adfuller(series.dropna())
    print(f'{name} ADF Statistic: {result[0]}')
    print(f'{name} p-value: {result[1]}')
    if result[1] > 0.05:
        print(f"{name} is not stationary. Differencing may be needed.")
    else:
        print(f"{name} is stationary.")

check_stationarity(merged_data['XLE_Returns'], 'XLE_Returns')
check_stationarity(merged_data['Interest_Rate'], 'Interest_Rate')
check_stationarity(merged_data['Crude_Oil_Price'], 'Crude_Oil_Price')
# Out:
# XLE_Returns ADF Statistic: -10.446964576432972
# XLE_Returns p-value: 1.4715789208373968e-18
# XLE_Returns is stationary.
# Interest_Rate ADF Statistic: -0.28942047851573927
# Interest_Rate p-value: 0.9269894014528836
# Interest_Rate is not stationary. Differencing may be needed.
# Crude_Oil_Price ADF Statistic: -1.468194596747374
# Crude_Oil_Price p-value: 0.5491822756484359
# Crude_Oil_Price is not stationary. Differencing may be needed.

# %%
merged_data['Interest_Rate_Diff'] = merged_data['Interest_Rate'].diff()
merged_data['Crude_Oil_Price_Diff'] = merged_data['Crude_Oil_Price'].diff()

check_stationarity(merged_data['Interest_Rate_Diff'], 'Interest_Rate_Diff')
check_stationarity(merged_data['Crude_Oil_Price_Diff'], 'Crude_Oil_Price_Diff')
# Out:
# Interest_Rate_Diff ADF Statistic: -24.240947535015234
# Interest_Rate_Diff p-value: 0.0
# Interest_Rate_Diff is stationary.
# Crude_Oil_Price_Diff ADF Statistic: -22.330241416497582
# Crude_Oil_Price_Diff p-value: 0.0
# Crude_Oil_Price_Diff is stationary.

# %%
from statsmodels.tsa.api import VAR
var_data = merged_data[['XLE_Returns', 'Interest_Rate_Diff', 'Crude_Oil_Price_Diff']].dropna()
var_model = VAR(var_data)
var_results = var_model.fit(maxlags=6)  
print(var_results.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 06, Dec, 2024
# Time:                     16:21:11
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                   -10.5809
# Nobs:                     998.000    HQIC:                  -10.7546
# Log likelihood:           1228.39    FPE:                1.91907e-05
# AIC:                     -10.8611    Det(Omega_mle):     1.81351e-05
# --------------------------------------------------------------------
# Results for equation XLE_Returns
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                           0.000852         0.000794            1.073           0.283
# L1.XLE_Returns                 -0.073599         0.035143           -2.094           0.036
# L1.Interest_Rate_Diff           0.003057         0.012573            0.243           0.808
# L1.Crude_Oil_Price_Diff         0.000577         0.000294            1.962           0.050
# L2.XLE_Returns                  0.062834         0.035415            1.774           0.076
# L2.Interest_Rate_Diff          -0.001473         0.012546           -0.117           0.907
# L2.Crude_Oil_Price_Diff         0.000072         0.000312            0.231           0.817
# L3.XLE_Returns                 -0.004971         0.035788           -0.139           0.890
# L3.Interest_Rate_Diff          -0.027551         0.012551           -2.195           0.028
# L3.Crude_Oil_Price_Diff         0.000111         0.000318            0.349           0.727
# L4.XLE_Returns                 -0.016313         0.035696           -0.457           0.648
# L4.Interest_Rate_Diff           0.005367         0.012579            0.427           0.670
# L4.Crude_Oil_Price_Diff         0.000357         0.000318            1.122           0.262
# L5.XLE_Returns                  0.068723         0.035732            1.923           0.054
# L5.Interest_Rate_Diff           0.011927         0.012546            0.951           0.342
# L5.Crude_Oil_Price_Diff        -0.000308         0.000311           -0.988           0.323
# L6.XLE_Returns                 -0.092175         0.035333           -2.609           0.009
# L6.Interest_Rate_Diff           0.021012         0.012527            1.677           0.093
# L6.Crude_Oil_Price_Diff         0.000058         0.000293            0.198           0.843
# ==========================================================================================
#
# Results for equation Interest_Rate_Diff
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                           0.002225         0.002057            1.082           0.279
# L1.XLE_Returns                 -0.218520         0.091068           -2.400           0.016
# L1.Interest_Rate_Diff           0.018335         0.032582            0.563           0.574
# L1.Crude_Oil_Price_Diff         0.001785         0.000762            2.344           0.019
# L2.XLE_Returns                  0.026756         0.091774            0.292           0.771
# L2.Interest_Rate_Diff          -0.085387         0.032511           -2.626           0.009
# L2.Crude_Oil_Price_Diff         0.001224         0.000809            1.512           0.130
# L3.XLE_Returns                  0.026777         0.092740            0.289           0.773
# L3.Interest_Rate_Diff          -0.044723         0.032525           -1.375           0.169
# L3.Crude_Oil_Price_Diff         0.000487         0.000825            0.590           0.555
# L4.XLE_Returns                 -0.275372         0.092502           -2.977           0.003
# L4.Interest_Rate_Diff           0.032893         0.032596            1.009           0.313
# L4.Crude_Oil_Price_Diff         0.000959         0.000824            1.164           0.245
# L5.XLE_Returns                  0.199953         0.092595            2.159           0.031
# L5.Interest_Rate_Diff           0.022114         0.032512            0.680           0.496
# L5.Crude_Oil_Price_Diff         0.000115         0.000807            0.142           0.887
# L6.XLE_Returns                  0.026590         0.091562            0.290           0.772
# L6.Interest_Rate_Diff           0.005114         0.032463            0.158           0.875
# L6.Crude_Oil_Price_Diff         0.000964         0.000761            1.267           0.205
# ==========================================================================================
#
# Results for equation Crude_Oil_Price_Diff
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                          -0.010881         0.093937           -0.116           0.908
# L1.XLE_Returns                  9.477325         4.158394            2.279           0.023
# L1.Interest_Rate_Diff          -0.542786         1.487757           -0.365           0.715
# L1.Crude_Oil_Price_Diff        -0.324321         0.034776           -9.326           0.000
# L2.XLE_Returns                 21.380887         4.190620            5.102           0.000
# L2.Interest_Rate_Diff           0.704069         1.484510            0.474           0.635
# L2.Crude_Oil_Price_Diff        -0.223435         0.036963           -6.045           0.000
# L3.XLE_Returns                  7.354222         4.234737            1.737           0.082
# L3.Interest_Rate_Diff          -0.207450         1.485172           -0.140           0.889
# L3.Crude_Oil_Price_Diff        -0.145698         0.037676           -3.867           0.000
# L4.XLE_Returns                  3.929668         4.223838            0.930           0.352
# L4.Interest_Rate_Diff          -1.240742         1.488402           -0.834           0.405
# L4.Crude_Oil_Price_Diff        -0.076076         0.037628           -2.022           0.043
# L5.XLE_Returns                  0.709325         4.228113            0.168           0.867
# L5.Interest_Rate_Diff          -0.752759         1.484590           -0.507           0.612
# L5.Crude_Oil_Price_Diff        -0.049166         0.036842           -1.335           0.182
# L6.XLE_Returns                  0.445137         4.180925            0.106           0.915
# L6.Interest_Rate_Diff           1.564165         1.482351            1.055           0.291
# L6.Crude_Oil_Price_Diff        -0.038706         0.034729           -1.114           0.265
# ==========================================================================================
#
# Correlation matrix of residuals
#                         XLE_Returns  Interest_Rate_Diff  Crude_Oil_Price_Diff
# XLE_Returns                1.000000            0.200221              0.395981
# Interest_Rate_Diff         0.200221            1.000000              0.112829
# Crude_Oil_Price_Diff       0.395981            0.112829              1.000000
# /Users/joey/opt/anaconda3/envs/study/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.

# %% [markdown]
# It's working better!

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox
lb_test = acorr_ljungbox(var_results.resid['XLE_Returns'], lags=[10], return_df=True)
print(lb_test)
# Out:
#       lb_stat  lb_pvalue
# 10  23.769979   0.008235

# %% [markdown]
# # Mean Reversion of XLE Returns
# 当前回报率会根据前期过度波动进行调整，表现出一定的均值回归趋势。
#
# # Crude Oil Prices as a Direct Driver
# 原油价格是能源股盈利的核心驱动力，其变化会直接影响能源股的表现。
#
# # Lagged Effect of Interest Rates (L3.Interest_Rate_Diff):
# 利率的变动通过融资成本或需求传导，延迟 3 个时期后对能源股产生负面影响。
#
# # future
